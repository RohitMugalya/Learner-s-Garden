# %%
import numpy as np
from matplotlib import pyplot as plt

plt.style.use("dark_background")

# %%
def graphit(arr):
    print(','.join(str(val) for val in arr))
    plt.plot(arr)

# %%
tc1 = [1, 3, 1]
tc2 = [2, 1, 1, 5, 6, 2, 3, 1]
tc3 = [1, 2, 3, 4, 5, 4]

tc4 = np.random.randint(1, 7, size=10)

# %%
graphit(tc4)
# Out:
# 5,6,3,4,6,3,1,3,4,3
