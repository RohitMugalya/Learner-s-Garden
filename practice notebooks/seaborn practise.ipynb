# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("../mpl styles/dracula.mplstyle")

# %%
tips = sns.load_dataset("tips")

total_bill = "total_bill"
tip = "tip"
gender = "sex"
smoker = "smoker"
day, time, size = "day", "time", "size"

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(data=tips, x=gender, hue=smoker)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
dummy_data = np.arange(100)
df = pd.concat([
    pd.DataFrame({"class": "A", "y": dummy_data}),
    pd.DataFrame({"class": "B", "y": np.random.choice([25, 50, 75], size=dummy_data.size)}),
])

# %%
sns.violinplot(data=df, x="class", y="y", fill=True, width=0.2)
# Out:
# <Axes: xlabel='class', ylabel='y'>
