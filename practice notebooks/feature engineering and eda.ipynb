# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from qbstyles import mpl_style

mpl_style()
pd.options.display.float_format = "{:.2f}".format

# %%
mpg = sns.load_dataset("mpg")
mpg.drop('name', axis='columns', inplace=True)
mpg.dropna(inplace=True)

# %%
print(mpg.shape)
mpg.head()
# Out:
# (392, 8)
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0 18.00          8        307.00      130.00    3504         12.00
# 1 15.00          8        350.00      165.00    3693         11.50
# 2 18.00          8        318.00      150.00    3436         11.00
# 3 16.00          8        304.00      150.00    3433         12.00
# 4 17.00          8        302.00      140.00    3449         10.50
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
sns.relplot(mpg, x='horsepower', y='mpg', col='cylinders', kind='scatter', color='white')

# %%
sns.scatterplot(mpg, x='weight', y='mpg', hue='cylinders')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
origin_wise = mpg.groupby('origin')
cylinders_wise = mpg.groupby('cylinders')

# %%
origin_wise.mean().T
# Out:
# origin        europe   japan     usa
# mpg            27.60   30.45   20.03
# cylinders       4.16    4.10    6.28
# displacement  109.63  102.71  247.51
# horsepower     80.56   79.84  119.05
# weight       2433.47 2221.23 3372.49
# acceleration   16.79   16.17   14.99
# model_year     75.68   77.44   75.59

# %%
sns.histplot(mpg, x='mpg', color='tomato')
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(x=mpg[mpg['origin'] == 'usa']['mpg'], color='green')
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.countplot(mpg, x='cylinders', hue='origin')
# Out:
# <Axes: xlabel='cylinders', ylabel='count'>

# %%
cylinders_wise.mean(numeric_only=True).T
# Out:
# cylinders          3       4       5       6       8
# mpg            20.55   29.28   27.37   19.97   14.96
# displacement   72.50  109.67  145.00  218.36  345.01
# horsepower     99.25   78.28   82.33  101.51  158.30
# weight       2398.50 2305.11 3103.33 3202.12 4114.72
# acceleration   13.25   16.58   18.63   16.25   12.96
# model_year     75.50   77.03   79.00   75.95   73.90
