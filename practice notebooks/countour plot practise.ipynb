# %%
import numpy as np
import matplotlib.pyplot as plt
from qbstyles import mpl_style

mpl_style(dark=True)

# %%
x = np.arange(-10, 10)
y = x.copy()
X, Y = np.meshgrid(x, y)
w1, w2 = 100, 100
Z = w1 * X ** 2 + w2 * Y ** 2

plt.contour(X, Y, Z)
plt.scatter(x, y, color="yellow")
