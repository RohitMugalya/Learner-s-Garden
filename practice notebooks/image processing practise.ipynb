# %%
from PIL import Image

# %%
img = Image.open(r"E:\HW files\Python Program Files\Image processing PIL programs\images\fire-ice fist.jpeg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>
